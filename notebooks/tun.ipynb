# %%
import pandas as pd
import numpy as np
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
df = pd.read_csv('../data/1900-01-01-2025-06-18-Northern_Africa-Tunisia.csv', usecols=['event_type', 'sub_event_type', 'fatalities', 'year'])
print("Event types:\n", df['event_type'].value_counts())
print("Sub-event types:\n", df['sub_event_type'].value_counts())
print("Fatalities distribution:\n", df['fatalities'].value_counts())
print("Events by year:\n", df['year'].value_counts().sort_index())
# Out:
# Event types:
#  event_type
# Protests                      8519
# Riots                         1905
# Battles                        307
# Explosions/Remote violence     227
# Strategic developments         225
# Violence against civilians     184
# Name: count, dtype: int64
# Sub-event types:
#  sub_event_type
# Peaceful protest                      8189
# Violent demonstration                 1661
# Armed clash                            307
# Protest with intervention              284
# Mob violence                           244
# Attack                                 172
# Remote explosive/landmine/IED          163
# Looting/property destruction            53
# Change to group/activity                48
# Arrests                                 47
# Excessive force against protesters      46
# Disrupted weapons use                   35
# Shelling/artillery/missile attack       32
# Other                                   32
# Air/drone strike                        28
# ...
